# %%
import pandas as pd
from pysmartdatamodels import pysmartdatamodels as sdm

# %%
smartDataModels = sdm.load_all_datamodels()

# %%
attributes = sdm.load_all_attributes()

# %%
attributes
# Out:
# [{'_id': {'$oid': '60b98736367efc6c60d96807'},
#   'property': 'id',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'Unique identifier of the entity',
#   'typeNGSI': 'Property',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d96808'},
#   'property': 'dateCreated',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Entity creation timestamp. This will usually be allocated by the storage platform.',
#   'typeNGSI': 'Property',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d96809'},
#   'property': 'dateModified',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Timestamp of the last modification of the entity. This will usually be allocated by the storage platform.',
#   'typeNGSI': 'Property',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d9680a'},
#   'property': 'source',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'A sequence of characters giving the original source of the entity data as a URL. Recommended to be the fully qualified domain name of the source provider, or the URL to the source object.',
#   'typeNGSI': 'Property',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d9680b'},
#   'property': 'name',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'The name of this item.',
#   'typeNGSI': 'Property',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d9680c'},
#   'property': 'alternateName',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'An alternative name for this item',
#   'typeNGSI': 'Property',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d9680d'},
#   'property': 'description',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'A description of this item',
#   'typeNGSI': 'Property',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d9680e'},
#   'property': 'dataProvider',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'A sequence of characters identifying the provider of the harmonised data entity.',
#   'typeNGSI': 'Property',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d9680f'},
#   'property': 'owner',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'A List containing a JSON encoded sequence of characters referencing the unique Ids of the owner(s)',
#   'typeNGSI': 'Property',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d96810'},
#   'property': 'seeAlso',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'list of uri pointing to additional resources about the item',
#   'typeNGSI': 'Property',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d96811'},
#   'property': 'location',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Geojson reference to the item. It can be Point, LineString, Polygon, MultiPoint, MultiLineString or MultiPolygon',
#   'typeNGSI': 'Geoproperty',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d96812'},
#   'property': 'address',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'The mailing address',
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/address',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d96813'},
#   'property': 'areaServed',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'The geographic area where a service or offered item is provided',
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/Text',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d96814'},
#   'property': 'type',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'NGSI type. It has to be Control',
#   'typeNGSI': 'Property',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d96815'},
#   'property': 'PowerSystemResource',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'number',
#   'description': 'The controller outputs used to actually govern a regulating device, e.g. the magnetization of a synchronous machine or capacitor bank breaker actuator. Default: None',
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/Number',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d96816'},
#   'property': 'controlType',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'number',
#   'description': "Specifies the type of Control, e.g. BreakerOn/Off, GeneratorVoltageSetPoint, TieLineFlow etc. The ControlType.name shall be unique among all specified types and describe the type. Default: ''",
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/Number',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d96817'},
#   'property': 'operationInProgress',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'number',
#   'description': 'Indicates that a client is currently sending control commands that has not completed. Default: False',
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/Number',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d96818'},
#   'property': 'timeStamp',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'number',
#   'description': "The last time a control output was sent. Default: ''",
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/Number',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d96819'},
#   'property': 'unitMultiplier',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'number',
#   'description': 'The unit multiplier of the controlled quantity. Default: None',
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/Number',
#   'modelTags': ''},
#  {'_id': {'$oid': '60b98736367efc6c60d9681a'},
#   'property': 'unitSymbol',
#   'dataModel': 'Control',
#   'repoName': 'dataModel.EnergyCIM',
#   'schemaVersion': '0.0.1',
#   'type': 'number',
#   'description': 'The unit of measure of the controlled quantity. Default: None',
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/Number',
#   'modelTags': ''},
#  {'_id': {'$oid': '64008ce86d89c83daa1beade'},
#   'property': 'credentialSchema',
#   'dataModel': 'AccreditedAttestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/AccreditedAttestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Contains information about the credential schema (template) on which the Verifiable Authorisation is based',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beadf'},
#   'property': 'credentialStatus',
#   'dataModel': 'AccreditedAttestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/AccreditedAttestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Contains information about how to verify the status of the Verifiable Attestation (via the Revocation and Endorsement Registry, RER)',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beae0'},
#   'property': 'credentialSubject',
#   'dataModel': 'AccreditedAttestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/AccreditedAttestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Defines information about the subject that is described by the Verifiable Attestation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beae1'},
#   'property': 'evidence',
#   'dataModel': 'AccreditedAttestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/AccreditedAttestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'Contains information about the process which resulted in the issuance of the Verifiable Attestation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beae2'},
#   'property': 'expirationDate',
#   'dataModel': 'AccreditedAttestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/AccreditedAttestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation expires',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beae3'},
#   'property': 'id',
#   'dataModel': 'AccreditedAttestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/AccreditedAttestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'uri',
#   'description': 'Defines unique identifier of the Verifiable Attestation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beae4'},
#   'property': 'issuanceDate',
#   'dataModel': 'AccreditedAttestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/AccreditedAttestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation becomes valid',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beae5'},
#   'property': 'issued',
#   'dataModel': 'AccreditedAttestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/AccreditedAttestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines when the Verifiable Attestation was issued',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beae6'},
#   'property': 'issuer',
#   'dataModel': 'AccreditedAttestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/AccreditedAttestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'uri',
#   'description': 'Defines the issuer of the Verifiable Attestation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beae7'},
#   'property': 'proof',
#   'dataModel': 'AccreditedAttestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/AccreditedAttestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Contains information about the proof',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beae8'},
#   'property': 'termsOfUse',
#   'dataModel': 'AccreditedAttestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/AccreditedAttestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'Contains the terms under which the Accredited Verifiable Attestation was issued',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beae9'},
#   'property': 'type',
#   'dataModel': 'AccreditedAttestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/AccreditedAttestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'Defines the Verifiable Credential type',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaea'},
#   'property': 'validFrom',
#   'dataModel': 'AccreditedAttestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/AccreditedAttestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation becomes valid',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaeb'},
#   'property': 'validUntil',
#   'dataModel': 'AccreditedAttestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/AccreditedAttestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation expires',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaed'},
#   'property': 'credentialSchema',
#   'dataModel': 'Attestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Attestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Contains information about the credential schema (template) on which the Verifiable Authorisation is based',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaee'},
#   'property': 'credentialStatus',
#   'dataModel': 'Attestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Attestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Contains information about how to verify the status of the Verifiable Attestation (via the Revocation and Endorsement Registry, RER)',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaef'},
#   'property': 'credentialSubject',
#   'dataModel': 'Attestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Attestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Defines information about the subject that is described by the Verifiable Attestation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaf0'},
#   'property': 'evidence',
#   'dataModel': 'Attestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Attestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'Contains information about the process which resulted in the issuance of the Verifiable Attestation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaf1'},
#   'property': 'expirationDate',
#   'dataModel': 'Attestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Attestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation expires',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaf2'},
#   'property': 'id',
#   'dataModel': 'Attestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Attestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'uri',
#   'description': 'Defines unique identifier of the Verifiable Attestation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaf3'},
#   'property': 'issuanceDate',
#   'dataModel': 'Attestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Attestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation becomes valid',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaf4'},
#   'property': 'issued',
#   'dataModel': 'Attestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Attestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines when the Verifiable Attestation was issued',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaf5'},
#   'property': 'issuer',
#   'dataModel': 'Attestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Attestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'uri',
#   'description': 'Defines the issuer of the Verifiable Attestation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaf6'},
#   'property': 'proof',
#   'dataModel': 'Attestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Attestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Contains information about the proof',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaf7'},
#   'property': 'type',
#   'dataModel': 'Attestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Attestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'Defines the Verifiable Credential type',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaf8'},
#   'property': 'validFrom',
#   'dataModel': 'Attestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Attestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation becomes valid',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce86d89c83daa1beaf9'},
#   'property': 'validUntil',
#   'dataModel': 'Attestation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Attestation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation expires',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beafb'},
#   'property': 'credentialSchema',
#   'dataModel': 'LegalEntity',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/LegalEntity/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Contains information about the credential schema (template) on which the Verifiable Authorisation is based',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beafc'},
#   'property': 'credentialStatus',
#   'dataModel': 'LegalEntity',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/LegalEntity/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Contains information about how to verify the status of the Verifiable Attestation (via the Revocation and Endorsement Registry, RER)',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beafd'},
#   'property': 'credentialSubject',
#   'dataModel': 'LegalEntity',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/LegalEntity/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Defines information about the subject that is described by the Verifiable ID',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beafe'},
#   'property': 'evidence',
#   'dataModel': 'LegalEntity',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/LegalEntity/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'Contains information about the process which resulted in the issuance of the Verifiable Attestation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beaff'},
#   'property': 'expirationDate',
#   'dataModel': 'LegalEntity',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/LegalEntity/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation expires',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb00'},
#   'property': 'id',
#   'dataModel': 'LegalEntity',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/LegalEntity/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'uri',
#   'description': 'Defines unique identifier of the Verifiable Attestation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb01'},
#   'property': 'issuanceDate',
#   'dataModel': 'LegalEntity',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/LegalEntity/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation becomes valid',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb02'},
#   'property': 'issued',
#   'dataModel': 'LegalEntity',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/LegalEntity/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines when the Verifiable Attestation was issued',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb03'},
#   'property': 'issuer',
#   'dataModel': 'LegalEntity',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/LegalEntity/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'uri',
#   'description': 'Defines the issuer of the Verifiable Attestation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb04'},
#   'property': 'proof',
#   'dataModel': 'LegalEntity',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/LegalEntity/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Contains information about the proof',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb05'},
#   'property': 'type',
#   'dataModel': 'LegalEntity',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/LegalEntity/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'Defines the Verifiable Credential type',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb06'},
#   'property': 'validFrom',
#   'dataModel': 'LegalEntity',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/LegalEntity/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation becomes valid',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb07'},
#   'property': 'validUntil',
#   'dataModel': 'LegalEntity',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/LegalEntity/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation expires',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb09'},
#   'property': 'credentialSchema',
#   'dataModel': 'NaturalPerson',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/NaturalPerson/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Contains information about the credential schema (template) on which the Verifiable Authorisation is based',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb0a'},
#   'property': 'credentialStatus',
#   'dataModel': 'NaturalPerson',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/NaturalPerson/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Contains information about how to verify the status of the Verifiable Attestation (via the Revocation and Endorsement Registry, RER)',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb0b'},
#   'property': 'credentialSubject',
#   'dataModel': 'NaturalPerson',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/NaturalPerson/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Defines additional information about the subject that is described by the Verifiable ID',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb0c'},
#   'property': 'evidence',
#   'dataModel': 'NaturalPerson',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/NaturalPerson/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'Contains information about the process which resulted in the issuance of the Verifiable Attestation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb0d'},
#   'property': 'expirationDate',
#   'dataModel': 'NaturalPerson',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/NaturalPerson/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation expires',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb0e'},
#   'property': 'id',
#   'dataModel': 'NaturalPerson',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/NaturalPerson/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'uri',
#   'description': 'Defines unique identifier of the Verifiable Attestation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb0f'},
#   'property': 'issuanceDate',
#   'dataModel': 'NaturalPerson',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/NaturalPerson/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation becomes valid',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb10'},
#   'property': 'issued',
#   'dataModel': 'NaturalPerson',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/NaturalPerson/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines when the Verifiable Attestation was issued',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb11'},
#   'property': 'issuer',
#   'dataModel': 'NaturalPerson',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/NaturalPerson/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'uri',
#   'description': 'Defines the issuer of the Verifiable Attestation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb12'},
#   'property': 'proof',
#   'dataModel': 'NaturalPerson',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/NaturalPerson/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Contains information about the proof',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb13'},
#   'property': 'type',
#   'dataModel': 'NaturalPerson',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/NaturalPerson/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'Defines the Verifiable Credential type',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb14'},
#   'property': 'validFrom',
#   'dataModel': 'NaturalPerson',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/NaturalPerson/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation becomes valid',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008ce96d89c83daa1beb15'},
#   'property': 'validUntil',
#   'dataModel': 'NaturalPerson',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/NaturalPerson/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Defines the date and time, when the Verifiable Attestation expires',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008cea6d89c83daa1beb17'},
#   'property': 'holder',
#   'dataModel': 'Presentation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Presentation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'Defines unique identifier of the party who shares the Verifiable Presentation',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008cea6d89c83daa1beb18'},
#   'property': 'proof',
#   'dataModel': 'Presentation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Presentation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'Contains information about the proof',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008cea6d89c83daa1beb19'},
#   'property': 'type',
#   'dataModel': 'Presentation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Presentation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'Defines the Verifiable Presentation type',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008cea6d89c83daa1beb1a'},
#   'property': 'verifiableCredential',
#   'dataModel': 'Presentation',
#   'repoName': 'dataModel.VerifiableCredentials',
#   'modelTags': 'EBSI, Verifiable Credentials',
#   'license': 'https://github.com/smart-data-models/dataModel.VerifiableCredentials/blob/master/Presentation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'Contains the personal information intended to be shared',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83a7'},
#   'property': 'accuracy',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'number',
#   'description': 'Accuracy measures the maximum systematic numerical error produced in a sensor measurement.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83a8'},
#   'property': 'address',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'object',
#   'description': 'The mailing address',
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/address'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83a9'},
#   'property': 'alternateName',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'string',
#   'description': 'An alternative name for this item',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83aa'},
#   'property': 'areaServed',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'string',
#   'description': 'The geographic area where a service or offered item is provided',
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/Text'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83ab'},
#   'property': 'completeness',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'number',
#   'description': 'Completeness quantifies the number of missed measurements or observations in a given time window',
#   'typeNGSI': 'Property',
#   'units': 'P1.'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83ac'},
#   'property': 'dataProvider',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'string',
#   'description': 'A sequence of characters identifying the provider of the harmonised data entity.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83ad'},
#   'property': 'dateCalculated',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Date of the calculated entity defined by the user.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83ae'},
#   'property': 'dateCreated',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Entity creation timestamp. This will usually be allocated by the storage platform.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83af'},
#   'property': 'dateModified',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Timestamp of the last modification of the entity. This will usually be allocated by the storage platform.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83b0'},
#   'property': 'description',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'string',
#   'description': 'A description of this item',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83b1'},
#   'property': 'id',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'string',
#   'description': 'Unique identifier of the entity',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83b2'},
#   'property': 'location',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'description': 'Geojson reference to the item. It can be Point, LineString, Polygon, MultiPoint, MultiLineString or MultiPolygon',
#   'typeNGSI': 'GeoProperty'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83b3'},
#   'property': 'name',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'string',
#   'description': 'The name of this item.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83b4'},
#   'property': 'outlier',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'object',
#   'description': 'Includes information about the outlier characteristics of the measurement.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83b5'},
#   'property': 'owner',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'array',
#   'description': 'A List containing a JSON encoded sequence of characters referencing the unique Ids of the owner(s)',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83b6'},
#   'property': 'precision',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'number',
#   'description': 'Precision measures the standard deviation of a dataset. That is, it measures how close the values in the dataset are to each other.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83b7'},
#   'property': 'seeAlso',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'description': 'list of uri pointing to additional resources about the item',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83b8'},
#   'property': 'source',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'string',
#   'description': 'A sequence of characters giving the original source of the entity data as a URL. Recommended to be the fully qualified domain name of the source provider, or the URL to the source object.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83b9'},
#   'property': 'synthetic',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'object',
#   'description': 'Includes information about the origin of the measurement.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83ba'},
#   'property': 'timeliness',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'number',
#   'description': 'Average timeliness of the data-stream',
#   'typeNGSI': 'Property',
#   'units': 'minutes.'},
#  {'_id': {'$oid': '64008d24095d2512ea4b83bb'},
#   'property': 'type',
#   'dataModel': 'DataQualityAssessment',
#   'repoName': 'dataModel.DataQuality',
#   'modelTags': '',
#   'license': 'https://github.com/smart-data-models/dataModel.DataQuality/blob/master/DataQualityAssessment/LICENSE.md',
#   'schemaVersion': '0.0.2',
#   'type': 'string',
#   'description': 'NGSI Entity type. It has to be DataQualityAssessment',
#   'typeNGSI': 'Property',
#   'enum': ['DataQualityAssessment']},
#  {'_id': {'$oid': '64008d55966d3d9beb91b883'},
#   'property': 'address',
#   'dataModel': 'Observation',
#   'repoName': 'dataModel.SDMX',
#   'modelTags': 'Interstat',
#   'license': 'https://github.com/smart-data-models/dataModel.SDMX/blob/master/Observation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'The mailing address',
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/address'},
#  {'_id': {'$oid': '64008d55966d3d9beb91b884'},
#   'property': 'alternateName',
#   'dataModel': 'Observation',
#   'repoName': 'dataModel.SDMX',
#   'modelTags': 'Interstat',
#   'license': 'https://github.com/smart-data-models/dataModel.SDMX/blob/master/Observation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'An alternative name for this item',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '64008d55966d3d9beb91b885'},
#   'property': 'areaServed',
#   'dataModel': 'Observation',
#   'repoName': 'dataModel.SDMX',
#   'modelTags': 'Interstat',
#   'license': 'https://github.com/smart-data-models/dataModel.SDMX/blob/master/Observation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'The geographic area where a service or offered item is provided',
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/Text'},
#  {'_id': {'$oid': '64008d55966d3d9beb91b886'},
#   'property': 'confStatus',
#   'dataModel': 'Observation',
#   'repoName': 'dataModel.SDMX',
#   'modelTags': 'Interstat',
#   'license': 'https://github.com/smart-data-models/dataModel.SDMX/blob/master/Observation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'Confidentiality Status (CONF_STATUS). This code list provides coded information about the sensitivity and confidentiality status of the data. The different values are defined based in Code List Confidentially Status v1.3 (https://sdmx.org/wp-content/uploads/CL_CONF_STATUS_1_3_2022.docx)',
#   'typeNGSI': 'Property',
#   'model': 'http://purl.org/linked-data/sdmx/2009/code#confStatus',
#   'enum': ['F', 'N', 'C', 'D', 'S', 'A', 'O', 'T', 'G', 'M', 'E', 'P']},
#  {'_id': {'$oid': '64008d55966d3d9beb91b887'},
#   'property': 'dataProvider',
#   'dataModel': 'Observation',
#   'repoName': 'dataModel.SDMX',
#   'modelTags': 'Interstat',
#   'license': 'https://github.com/smart-data-models/dataModel.SDMX/blob/master/Observation/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
# ...
#   'dataModel': 'atmosphericPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/atmosphericPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'A List containing a JSON encoded sequence of characters referencing the unique Ids of the owner(s)',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceb98'},
#   'property': 'precision',
#   'dataModel': 'atmosphericPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/atmosphericPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'number',
#   'description': "When exposed the value in 'precision' provides a +/- tolerance against the Properties in the Resource. Thus if a Property is UPDATED to a value and that Property then RETRIEVED, the RETRIEVED value is valid if in the range of the set value +/- precision",
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceb99'},
#   'property': 'range',
#   'dataModel': 'atmosphericPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/atmosphericPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'The valid range for the Property in the Resource as a number. The first value in the array is the minimum value, the second value in the array is the maximum value.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceb9a'},
#   'property': 'rt',
#   'dataModel': 'atmosphericPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/atmosphericPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'The Resource Type.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceb9b'},
#   'property': 'seeAlso',
#   'dataModel': 'atmosphericPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/atmosphericPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'description': 'list of uri pointing to additional resources about the item',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceb9c'},
#   'property': 'source',
#   'dataModel': 'atmosphericPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/atmosphericPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'A sequence of characters giving the original source of the entity data as a URL. Recommended to be the fully qualified domain name of the source provider, or the URL to the source object.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceb9d'},
#   'property': 'step',
#   'dataModel': 'atmosphericPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/atmosphericPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'number',
#   'description': 'Step value across the defined range an integer when the range is a number.  This is the increment for valid values across the range; so if range is 0.0..10.0 and step is 2.5 then valid values are 0.0,2.5,5.0,7.5,10.0.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceb9e'},
#   'property': 'type',
#   'dataModel': 'atmosphericPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/atmosphericPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'NGSI entity type. It has to be atmosphericPressure',
#   'typeNGSI': 'Property',
#   'enum': ['atmosphericPressure']},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceba0'},
#   'property': 'address',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'The mailing address',
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/address'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceba1'},
#   'property': 'alternateName',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'An alternative name for this item',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceba2'},
#   'property': 'areaServed',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'The geographic area where a service or offered item is provided',
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/Text'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceba3'},
#   'property': 'dataProvider',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'A sequence of characters identifying the provider of the harmonised data entity.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceba4'},
#   'property': 'dateCreated',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Entity creation timestamp. This will usually be allocated by the storage platform.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceba5'},
#   'property': 'dateModified',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'format': 'date-time',
#   'description': 'Timestamp of the last modification of the entity. This will usually be allocated by the storage platform.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceba6'},
#   'property': 'description',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'A description of this item',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceba7'},
#   'property': 'diastolic',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'number',
#   'description': 'Diastolic blood pressure',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceba8'},
#   'property': 'id',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'Unique identifier of the entity',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58ceba9'},
#   'property': 'if',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'The OCF Interface set supported by this Resource',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebaa'},
#   'property': 'location',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'description': 'Geojson reference to the item. It can be Point, LineString, Polygon, MultiPoint, MultiLineString or MultiPolygon',
#   'typeNGSI': 'GeoProperty'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebab'},
#   'property': 'map',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'number',
#   'description': 'Mean arterial pressure (MAP)',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebac'},
#   'property': 'n',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'Friendly name of the Resource',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebad'},
#   'property': 'name',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'The name of this item.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebae'},
#   'property': 'owner',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'A List containing a JSON encoded sequence of characters referencing the unique Ids of the owner(s)',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebaf'},
#   'property': 'precision',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'number',
#   'description': "When exposed the value in 'precision' provides a +/- tolerance against the Properties in the Resource. Thus if a Property is UPDATED to a value and that Property then RETRIEVED, the RETRIEVED value is valid if in the range of the set value +/- precision",
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebb0'},
#   'property': 'range',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'The valid range for the Property in the Resource as a number. The first value in the array is the minimum value, the second value in the array is the maximum value.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebb1'},
#   'property': 'rt',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'array',
#   'description': 'Resource Type',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebb2'},
#   'property': 'seeAlso',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'description': 'list of uri pointing to additional resources about the item',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebb3'},
#   'property': 'source',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'A sequence of characters giving the original source of the entity data as a URL. Recommended to be the fully qualified domain name of the source provider, or the URL to the source object.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebb4'},
#   'property': 'step',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'number',
#   'description': 'Step value across the defined range an integer when the range is a number.  This is the increment for valid values across the range; so if range is 0.0..10.0 and step is 2.5 then valid values are 0.0,2.5,5.0,7.5,10.0.',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebb5'},
#   'property': 'systolic',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'number',
#   'description': 'Systolic blood pressure',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebb6'},
#   'property': 'type',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'NGSI entity type. It has to be BloodPressure',
#   'typeNGSI': 'Property',
#   'enum': ['BloodPressure']},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebb7'},
#   'property': 'units',
#   'dataModel': 'BloodPressure',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BloodPressure/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'Blood pressure unit',
#   'typeNGSI': 'Property',
#   'enum': ['mmHg', 'kPa']},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebb9'},
#   'property': 'address',
#   'dataModel': 'BMI',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BMI/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'object',
#   'description': 'The mailing address',
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/address'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebba'},
#   'property': 'alternateName',
#   'dataModel': 'BMI',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BMI/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'An alternative name for this item',
#   'typeNGSI': 'Property'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebbb'},
#   'property': 'areaServed',
#   'dataModel': 'BMI',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BMI/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'string',
#   'description': 'The geographic area where a service or offered item is provided',
#   'typeNGSI': 'Property',
#   'model': 'https://schema.org/Text'},
#  {'_id': {'$oid': '640094a3bc5b8dd0f58cebbc'},
#   'property': 'bmi',
#   'dataModel': 'BMI',
#   'repoName': 'dataModel.OCF',
#   'modelTags': 'OCF',
#   'license': 'https://github.com/smart-data-models/dataModel.OCF/blob/master/BMI/LICENSE.md',
#   'schemaVersion': '0.0.1',
#   'type': 'number',
#   'description': 'Body Mass Index (BMI) in kg/m^2',
#   'typeNGSI': 'Property'},
#  ...]

# %%
import random

random.choice(attributes)
# Out:
# {'_id': {'$oid': '6400ac3032dedbf617eac5e7'},
#  'property': 'address',
#  'dataModel': 'RotatingMachineDynamics',
#  'repoName': 'dataModel.EnergyCIM',
#  'modelTags': '',
#  'license': 'https://github.com/smart-data-models/dataModel.EnergyCIM/blob/master/RotatingMachineDynamics/LICENSE.md',
#  'schemaVersion': '0.0.1',
#  'type': 'object',
#  'description': 'The mailing address',
#  'typeNGSI': 'Property',
#  'model': 'https://schema.org/address'}

# %%
import requests
from pprint import pprint
import tqdm

def query_lov(query):
    # Possible types: [class, propery, datatype, instance]
    payload = {'q': query, 'page_size': 3000}
    try:
        r = requests.get('https://lov.linkeddata.es/dataset/lov/api/v2/term/search', params=payload)
        return r.json()
    except:
        return 'There was and error'

def search_lov(query):
    lov_results = query_lov(query)
    df = pd.DataFrame(lov_results['results'])
    df = df[['prefixedName', 'uri', 'score', 'type']]
    df['uri'] = df['uri'].apply(lambda x: x[0])
    df['prefixedName'] = df['prefixedName'].apply(lambda x: x[0])
    return df

def lov_printer(result):
    print(f"Search: {result['queryString']}")
    print(f"Results: {result['total_results']}")

    if result['total_results'] > 0:
        print(f"Entities: ")
        print(result['results'][0]['prefixedName'])
        print(result['results'][0]['score'])
        print(result['results'][0]['type'])
        print(result['results'][0]['uri'])
        print(result['results'][0]['vocabulary.prefix'])
        print(result['results'][0]['metrics.reusedByDatasets'])
    print()
    print('#' * 20)

# %%
properties = []
results = []
prefix_names = []
scores = []
types = []
uris = []
vocab_prefixs = []
reusedby = []

seen_attributes = []

for a in tqdm.tqdm(attributes[:3]):
    if a['property'] not in seen_attributes:
        try:
            lov_result = query_lov(a['property'])
            print(lov_result['total_results'])

            for r in lov_result['results']:
                if r['score'] > 0.2:
                    properties.append(a['property'])
                    results.append(lov_result['total_results'])
                    prefix_names.append(r['prefixedName'][0])
                    scores.append(r['score'])
                    types.append(r['type'])
                    uris.append(r['uri'][0])
                    vocab_prefixs.append(r['vocabulary.prefix'][0])
                    reusedby.append(r['metrics.reusedByDatasets'][0])
                else:
                    next
        except:
            print(f"Error: {a['property']}")
        
        seen_attributes.append(a['property'])
    else:
        next
# Out:
#  33%|███▎      | 1/3 [00:04<00:09,  4.95s/it]
# 2948
#  67%|██████▋   | 2/3 [00:06<00:02,  2.82s/it]
# 10
# 100%|██████████| 3/3 [00:07<00:00,  2.61s/it]
# 7

# %%
sdm_lov_df = pd.DataFrame(
    {
        'property' : properties,
        'num_results' : results,
        'prefix_name' : prefix_names,
        'score' : scores,
        'type' : types,
        'uri' : uris,
        'vocab_prefix' : vocab_prefixs,
        'reused_by' : reusedby
    }
)

# %%
sdm_lov_df.to_csv('datasets/sdm_lov_df.csv', index=False)
